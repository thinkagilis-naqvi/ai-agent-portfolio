# %% [markdown]
# <a href="https://colab.research.google.com/github/thinkagilis-naqvi/ai-agent-portfolio/blob/main/AI_Multi_Agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introduction to Agents**
#
# AI is evolving...
#
#  From narrow, human-directed tools to autonomous systems capable of independent problem-solving and execution. This paradigm shift moves beyond passive task completion to active workflow automation, reducing human overhead while unlocking new levels of scale and efficiency.
#
# AI agents mark the next evolution: autonomous systems that independently plan and execute complex workflows. Combining reasoning with action, they operate without constant human direction, transforming AI from a passive tool into a self-sufficient problem-solving engine.

# %% [markdown]
# ### 1. Install Google ADK
# ###

# %%
# Install and use Google ADK for this notebook
# !pip install -U google-adk
# Out:
# Requirement already satisfied: google-adk in /usr/local/lib/python3.12/dist-packages (1.17.0)
# Collecting google-adk
#   Downloading google_adk-1.18.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: PyYAML<7.0.0,>=6.0.2 in /usr/local/lib/python3.12/dist-packages (from google-adk) (6.0.3)
# Requirement already satisfied: anyio<5.0.0,>=4.9.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (4.11.0)
# Requirement already satisfied: authlib<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.6.5)
# Requirement already satisfied: click<9.0.0,>=8.1.8 in /usr/local/lib/python3.12/dist-packages (from google-adk) (8.3.0)
# Requirement already satisfied: fastapi<1.119.0,>=0.115.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.121.1)
# Requirement already satisfied: google-api-python-client<3.0.0,>=2.157.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.187.0)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.125.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.126.1)
# Requirement already satisfied: google-cloud-bigtable>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.34.0)
# Requirement already satisfied: google-cloud-discoveryengine<0.14.0,>=0.13.12 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.13.12)
# Requirement already satisfied: google-cloud-secret-manager<3.0.0,>=2.22.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.25.0)
# Requirement already satisfied: google-cloud-spanner<4.0.0,>=3.56.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (3.59.0)
# Requirement already satisfied: google-cloud-speech<3.0.0,>=2.30.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.34.0)
# Collecting google-cloud-storage<4.0.0,>=3.0.0 (from google-adk)
#   Downloading google_cloud_storage-3.5.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: google-genai<2.0.0,>=1.45.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.49.0)
# Requirement already satisfied: graphviz<1.0.0,>=0.20.2 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.21)
# Requirement already satisfied: mcp<2.0.0,>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.21.0)
# Requirement already satisfied: opentelemetry-api<=1.37.0,>=1.37.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-exporter-gcp-logging<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-exporter-gcp-trace<2.0.0,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.11.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.36.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-resourcedetector-gcp<2.0.0,>=1.9.0a0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.11.0a0)
# Requirement already satisfied: opentelemetry-sdk<=1.37.0,>=1.37.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.37.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.11.10)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.9.0.post0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.9.0.post0)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.32.4 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.32.4)
# Requirement already satisfied: sqlalchemy-spanner>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (1.17.1)
# Requirement already satisfied: sqlalchemy<3.0.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (2.0.44)
# Requirement already satisfied: starlette<1.0.0,>=0.46.2 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.49.3)
# Collecting tenacity<10.0.0,>=9.0.0 (from google-adk)
#   Downloading tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5,>=4.5 in /usr/local/lib/python3.12/dist-packages (from google-adk) (4.15.0)
# Requirement already satisfied: tzlocal<6.0,>=5.3 in /usr/local/lib/python3.12/dist-packages (from google-adk) (5.3.1)
# Requirement already satisfied: uvicorn<1.0.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (0.38.0)
# Requirement already satisfied: watchdog<7.0.0,>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from google-adk) (6.0.0)
# Requirement already satisfied: websockets<16.0.0,>=15.0.1 in /usr/local/lib/python3.12/dist-packages (from google-adk) (15.0.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (3.11)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.9.0->google-adk) (1.3.1)
# Requirement already satisfied: cryptography in /usr/local/lib/python3.12/dist-packages (from authlib<2.0.0,>=1.5.1->google-adk) (43.0.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.119.0,>=0.115.0->google-adk) (0.0.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.31.0)
# Requirement already satisfied: google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.38.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.2.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (2.28.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.2.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (5.29.5)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.38.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.15.0)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.1.2)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.17.0)
# Requirement already satisfied: cloudpickle<4.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.1.2)
# Requirement already satisfied: google-cloud-trace<2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.17.0)
# Requirement already satisfied: google-cloud-logging<4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (3.12.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=1.4.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (2.5.0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.12.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (0.14.3)
# Requirement already satisfied: google-crc32c<2.0.0dev,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigtable>=2.32.0->google-adk) (1.7.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-secret-manager<3.0.0,>=2.22.0->google-adk) (1.76.0)
# Requirement already satisfied: sqlparse>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.5.3)
# Requirement already satisfied: grpc-interceptor>=0.15.4 in /usr/local/lib/python3.12/dist-packages (from google-cloud-spanner<4.0.0,>=3.56.0->google-adk) (0.15.4)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage<4.0.0,>=3.0.0->google-adk) (2.7.2)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.45.0->google-adk) (0.28.1)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (2.12.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.8.0->google-adk) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (0.0.20)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.8.0->google-adk) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (8.7.0)
# Requirement already satisfied: google-cloud-monitoring~=2.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-gcp-monitoring<2.0.0,>=1.9.0a0->google-adk) (2.28.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-proto==1.37.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-http>=1.36.0->google-adk) (1.37.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<=1.37.0,>=1.37.0->google-adk) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.0->google-adk) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.9.0.post0->google-adk) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.4->google-adk) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3.0.0,>=2.0->google-adk) (3.2.4)
# Requirement already satisfied: alembic in /usr/local/lib/python3.12/dist-packages (from sqlalchemy-spanner>=1.14.0->google-adk) (1.17.1)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1.0.0,>=0.34.0->google-adk) (0.16.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (4.9.1)
# Requirement already satisfied: google-cloud-appengine-logging<2.0.0,>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (1.7.0)
# Requirement already satisfied: google-cloud-audit-log<1.0.0,>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-logging<4->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (0.4.0)
# Requirement already satisfied: pyparsing<4,>=3.0.4 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (3.2.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.45.0->google-adk) (1.0.9)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<=1.37.0,>=1.37.0->google-adk) (3.23.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.8.0->google-adk) (0.28.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.0.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from shapely<3.0.0->google-cloud-aiplatform<2.0.0,>=1.125.0->google-cloud-aiplatform[agent-engines]<2.0.0,>=1.125.0->google-adk) (2.0.2)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic->sqlalchemy-spanner>=1.14.0->google-adk) (1.3.10)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography->authlib<2.0.0,>=1.5.1->google-adk) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client<3.0.0,>=2.157.0->google-adk) (0.6.1)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.12/dist-packages (from Mako->alembic->sqlalchemy-spanner>=1.14.0->google-adk) (3.0.3)
# Downloading google_adk-1.18.0-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 22.3 MB/s eta 0:00:00
# Downloading google_cloud_storage-3.5.0-py3-none-any.whl (289 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.0/290.0 kB 9.3 MB/s eta 0:00:00
# Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, google-cloud-storage, google-adk
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.5.0
#     Uninstalling tenacity-8.5.0:
#       Successfully uninstalled tenacity-8.5.0
#   Attempting uninstall: google-cloud-storage
#     Found existing installation: google-cloud-storage 2.19.0
#     Uninstalling google-cloud-storage-2.19.0:
#       Successfully uninstalled google-cloud-storage-2.19.0
#   Attempting uninstall: google-adk
#     Found existing installation: google-adk 1.17.0
#     Uninstalling google-adk-1.17.0:
#       Successfully uninstalled google-adk-1.17.0
# Successfully installed google-adk-1.18.0 google-cloud-storage-3.5.0 tenacity-9.1.2

# %%
# Install nest_asyncio
# !pip install nest_asyncio
# Out:
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (1.6.0)

# %% [markdown]
# ### 2. Configure your Gemini API Key
# * In the top left menu bar select the '**🗝**'
# * Click on '➕Add new secret'
# * Name the new key 'GOOGLE_API_KEY'
# * Paste yoru API Value
# * Slide the 'Notebook access' control to enable

# %%
from google.colab import userdata
userdata.get('GOOGLE_API_KEY')
# Out:
# 'AIzaSyDo2eKaUnQZUjz_N_DV0qAx2JcUn7p_Q8o'

# %%
import os
from google.colab import userdata


try:
    #Set GOOGLE_API_KEY from Colab Secrets
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Colab secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ###3. Import ADK Components
# * Import components needed from Agent Development Kit and the Generative AI library.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("✅ ADK components imported successfully.")

import nest_asyncio
nest_asyncio.apply()
print("✅ Nest Asyncio components imported successfully.")
# Out:
# ✅ ADK components imported successfully.
# ✅ Nest Asyncio components imported successfully.

# %% [markdown]
# ### 4. Configure Retry Options
# * When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# ### 5. Build Research & Summarization System
# * Research Agent - Searches for information using Google Search
# * Summarizer Agent - Creates concise summaries from research findings

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("✅ research_agent created.")
# Out:
# ✅ research_agent created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("✅ summarizer_agent created.")
# Out:
# ✅ summarizer_agent created.

# %% [markdown]
# ### 6. Root Coordinator
# * Orchestrates the workflow by callign the sub agents as tools

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("✅ root_agent created.")
# Out:
# ✅ root_agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum AI is set to revolutionize artificial intelligence by leveraging the immense computational power of quantum computers. Key advancements include exponential performance boosts for complex AI tasks, enhanced data processing capabilities, and the ability to solve intricate optimization problems. These developments are expected to transform industries such as healthcare, through accelerated drug discovery and personalized medicine, and mobility, with optimized traffic flow and autonomous systems. While challenges in hardware stability and algorithm scalability persist, significant progress is being made, with the potential for practical quantum AI applications within the next 5 to 10 years.

# %% [markdown]
# ## Sequential Agents

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("✅ outline_agent created.")
# Out:
# ✅ outline_agent created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("✅ writer_agent created.")
# Out:
# ✅ writer_agent created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("✅ editor_agent created.")
# Out:
# ✅ editor_agent created.

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("✅ Sequential Agent created.")
# Out:
# ✅ Sequential Agent created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ### Outline: Unlocking Superpowers: How Multi-Agent Systems Will Revolutionize Your Development Workflow
#
# **Introduction Hook:**
#
# Ever feel like you're juggling too many tasks, bogged down by repetitive coding, or struggling to manage complex system interactions? What if you could leverage an army of intelligent digital assistants to streamline your work, boost efficiency, and build more robust software? Enter Multi-Agent Systems (MAS), a powerful paradigm that's poised to transform how we develop software.
#
# **Main Sections:**
#
# **1. What Exactly Are Multi-Agent Systems?**
#
# *   **Defining the "Agent":** Explore the core concept of an agent – an autonomous, proactive, and reactive entity capable of perceiving its environment and acting upon it.
# *   **The "Multi" Advantage:** Explain how multiple agents interacting, collaborating, and even competing create emergent behaviors and solutions far beyond what a single agent or traditional program can achieve.
# *   **Beyond Simple Bots:** Differentiate MAS from basic chatbots or scripted automation by highlighting their intelligence, learning capabilities, and ability to adapt to dynamic environments.
#
# **2. Supercharging Your Development Process with MAS**
#
# *   **Automating Repetitive Tasks:** Discover how MAS can handle mundane coding, testing, and deployment tasks, freeing up developers for more creative and strategic work.
# *   **Enhanced Debugging and Testing:** Learn how agents can proactively identify bugs, simulate complex user scenarios, and even self-heal systems, leading to more stable software.
# *   **Intelligent System Monitoring and Management:** Explore how MAS can continuously monitor system performance, predict potential issues, and autonomously optimize resource allocation.
#
# **3. Building Smarter, More Resilient Software with MAS**
#
# *   **Decentralized and Robust Architectures:** Understand how MAS naturally lend themselves to distributed systems, making them more resilient to failures and scalable.
# *   **Complex Problem Solving:** See how MAS can tackle intricate challenges like optimizing supply chains, managing smart grids, or simulating intricate natural phenomena.
# *   **Personalized User Experiences:** Consider how agents can learn user preferences and adapt software behavior to provide highly tailored and engaging experiences.
#
# **4. Getting Started with Multi-Agent Systems: A Developer's Roadmap**
#
# *   **Key Technologies and Frameworks:** Introduce popular MAS frameworks (e.g., JADE, AgentPy, SPADE) and relevant programming languages.
# *   **Learning Resources and Communities:** Point developers towards valuable tutorials, documentation, and online communities to foster learning and collaboration.
# *   **Start Small, Think Big:** Offer practical advice on how to begin experimenting with MAS on smaller projects and gradually scale up to more complex applications.
#
# **Concluding Thought:**
#
# Multi-Agent Systems are no longer a futuristic concept; they are a tangible and increasingly accessible tool for software developers. By embracing this paradigm, you can not only become a more efficient and productive developer but also contribute to building the next generation of intelligent, adaptive, and resilient software. It's time to unlock your development superpowers!
# WriterAgent > ## Unlocking Superpowers: How Multi-Agent Systems Will Revolutionize Your Development Workflow
#
# Feeling buried under a mountain of code, repetitive tasks, and complex system management? Imagine an army of intelligent digital assistants working alongside you, streamlining your workflow and building more robust software. This isn't science fiction; it's the reality of Multi-Agent Systems (MAS), a paradigm set to transform how we develop.
#
# At its core, an agent is an autonomous entity that can perceive its environment and act upon it. The "multi" in MAS is where the magic happens. When multiple intelligent agents interact, collaborate, and even compete, they achieve emergent behaviors and solve problems far beyond the capabilities of a single program. These aren't just fancy chatbots; MAS agents possess intelligence, learning capabilities, and the ability to adapt to dynamic environments.
#
# So, how do these digital powerhouses benefit *your* development process?
#
# Firstly, MAS can **automate your most mundane tasks**. Think repetitive coding, exhaustive testing, and routine deployment – all handled by your agent army, freeing you for more creative and strategic endeavors. Secondly, MAS significantly **enhances debugging and testing**. Agents can proactively identify bugs, simulate complex user scenarios, and even self-heal systems, leading to drastically more stable software. Finally, MAS offers **intelligent system monitoring and management**. Agents can continuously track performance, predict issues, and autonomously optimize resource allocation, ensuring your systems run smoothly.
#
# Beyond efficiency, MAS allows you to build **smarter, more resilient software**. Their inherent decentralized nature makes systems robust and scalable. They excel at tackling intricate problems, from optimizing supply chains to managing smart grids, and can even create highly personalized user experiences by learning individual preferences.
#
# Ready to harness this power? Explore frameworks like JADE or AgentPy, dive into available tutorials, and start small. Embrace Multi-Agent Systems, and unlock your development superpowers!
# EditorAgent > ## Unlocking Superpowers: How Multi-Agent Systems Will Revolutionize Your Development Workflow
#
# Are you feeling overwhelmed by mountains of code, bogged down by repetitive tasks, and struggling with complex system management? Imagine having an army of intelligent digital assistants working seamlessly alongside you, streamlining your workflow and helping you build more robust software. This isn't a far-off dream; it's the emerging reality of Multi-Agent Systems (MAS), a paradigm set to fundamentally transform how we develop software.
#
# ### What Exactly Are Multi-Agent Systems?
#
# At its core, an **agent** is an autonomous entity that can perceive its environment and act upon it. It's proactive, reactive, and capable of goal-directed behavior. The true power, however, lies in the "multi." When multiple intelligent agents interact, collaborate, and even compete, they exhibit **emergent behaviors** and can solve problems far beyond the capabilities of any single program or agent. These aren't just simple chatbots or basic automation scripts; MAS agents possess genuine intelligence, learning capabilities, and the crucial ability to adapt to dynamic and unpredictable environments.
#
# ### Supercharging Your Development Process with MAS
#
# So, how do these digital powerhouses directly benefit *your* development workflow?
#
# *   **Automating Mundane Tasks:** MAS can take on your most tedious jobs. Imagine repetitive coding, exhaustive unit testing, and routine deployment procedures being handled by your agent army. This frees you and your team to focus on more creative problem-solving, architectural design, and strategic innovation.
# *   **Enhanced Debugging and Testing:** MAS significantly elevates your testing and debugging capabilities. Agents can proactively identify potential bugs before they become critical issues, simulate an incredibly diverse range of complex user scenarios, and even autonomously self-heal systems under certain conditions. The result? Drastically more stable and reliable software.
# *   **Intelligent System Monitoring and Management:** MAS provides sophisticated, ongoing oversight of your systems. Agents can continuously track performance metrics, predict potential bottlenecks or failures, and autonomously optimize resource allocation in real-time. This ensures your systems run smoothly, efficiently, and without constant manual intervention.
#
# ### Building Smarter, More Resilient Software with MAS
#
# Beyond immediate workflow efficiencies, MAS empowers you to build software that is inherently smarter and more resilient:
#
# *   **Decentralized and Robust Architectures:** The inherent nature of MAS lends itself perfectly to distributed and decentralized system designs. This makes your applications more robust against failures, highly scalable, and easier to manage in complex environments.
# *   **Tackling Intricate Problems:** MAS excel at solving complex, multi-faceted challenges that are difficult for traditional monolithic systems. Examples include optimizing intricate supply chains, managing dynamic smart grids, simulating complex natural phenomena, or orchestrating large-scale distributed computing tasks.
# *   **Creating Personalized User Experiences:** By learning individual user preferences and behaviors, agents can dynamically adapt software functionality and interfaces. This leads to highly personalized and engaging experiences that feel tailored to each user.
#
# ### Getting Started with Multi-Agent Systems: Your Developer's Roadmap
#
# Ready to harness the power of MAS? Here's how you can begin:
#
# *   **Explore Key Technologies:** Familiarize yourself with popular MAS frameworks such as JADE (Java Agent DEvelopment Framework), AgentPy (Python), or SPADE (Smart Python Agent Development Environment).
# *   **Leverage Learning Resources:** Dive into available tutorials, official documentation, and online communities dedicated to MAS development. Many platforms offer excellent starting points and support networks.
# *   **Start Small, Think Big:** Begin by experimenting with MAS on smaller, contained projects. Apply them to automate a specific repetitive task or simulate a simple interaction. As you gain confidence and understanding, you can gradually scale up to more complex and integrated applications.
#
# Multi-Agent Systems are no longer a theoretical concept confined to research labs. They are a tangible and increasingly accessible toolkit for modern software developers. By embracing this powerful paradigm, you can become a more efficient and productive developer and contribute to building the next generation of intelligent, adaptive, and resilient software. It's time to unlock your development superpowers!

# %% [markdown]
# ## Running Agents in Parallel

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("✅ tech_researcher created.")
# Out:
# ✅ tech_researcher created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("✅ health_researcher created.")
# Out:
# ✅ health_researcher created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("✅ finance_researcher created.")
# Out:
# ✅ finance_researcher created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}

    **Health Breakthroughs:**
    {health_research}

    **Finance Innovations:**
    {finance_research}

    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("✅ aggregator_agent created.")
# Out:
# ✅ aggregator_agent created.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("✅ Parallel and Sequential Agents created.")
# Out:
# ✅ Parallel and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# FinanceResearcher > **Tech, Health, and Finance Executive Briefing**
#
# **Technology:** The integration of AI into executive briefings is a significant trend. AI-powered "chiefs of staff" are now providing personalized, one-page summaries of crucial information, drawing from calendars and multiple data sources. This aims to save executives time and improve decision-making speed. The future outlook suggests AI will further enhance these briefings with deeper strategic modeling and personalized insights.
#
# **Health:** Executive briefings in healthcare focus on navigating complex market intelligence and expert analysis to guide strategy and improve organizational performance. Topics include integrated care models, digital health, and regulatory compliance. The future will likely see more emphasis on data quality for decision-making and adapting to shifts in care delivery.
#
# **Finance:** Fintech trends highlight AI-driven personalization and data synthesis. Executive briefings in finance are increasingly curated to distill critical market intelligence, competitive insights, and financial reports. The market implications are improved strategic planning and risk identification. The future points towards more sophisticated AI applications for enhanced financial forecasting and predictive alerts by integrating with CRM and supply systems.
# TechResearcher > **Key AI/ML Trends and Developments**
#
# The field of Artificial Intelligence (AI) and Machine Learning (ML) is rapidly evolving, with several key developments shaping its trajectory in 2025 and beyond.
#
# **1. Generative AI and Multimodal Models:** Generative AI continues its ascent, expanding beyond text generation to encompass images, video, and audio. Major players like OpenAI (ChatGPT), Google (Gemini), and Anthropic (Claude) are at the forefront of developing increasingly sophisticated large language models (LLMs) and multimodal models that can process and generate diverse data types. This trend is revolutionizing content creation, aiding software development, and enhancing creative workflows across industries.
#
# **2. AI Agents and Autonomous Systems:** The development of AI agents capable of independent action is gaining significant traction. Companies are exploring these agents for tasks ranging from business workflow management and scheduling to customer support and inventory management. This trend promises to enhance efficiency and reduce errors by automating complex tasks.
#
# **3. Explainable and Ethical AI:** As AI integration deepens, there's a growing emphasis on transparency and trustworthiness. Explainable AI (XAI) aims to make AI decision-making processes understandable, crucial for regulated sectors like healthcare and finance. This trend addresses ethical concerns surrounding algorithmic bias and fairness, building trust in AI systems.
#
# **Main Companies Involved:**
# *   **Generative AI/LLMs:** OpenAI, Google, Anthropic, Microsoft, Meta.
# *   **AI Infrastructure/Hardware:** NVIDIA, Google Cloud, Microsoft Azure, AWS.
# *   **Data & ML Platforms:** Databricks, DataRobot, Cloudera.
# *   **Specialized AI Solutions:** Synthesia (video generation), ElevenLabs (voice generation).
#
# **Potential Impact:**
# These AI/ML trends are poised to significantly transform industries by driving automation, enhancing decision-making, and creating new avenues for innovation. Businesses can expect increased productivity, improved customer experiences, and streamlined operations. However, challenges related to AI governance, data privacy, and workforce adaptation will also need to be addressed. The rapid advancement of AI necessitates continuous learning and strategic integration to harness its full potential while mitigating risks.
# HealthResearcher > **Health Breakthroughs:**
#
# 1.  **Gene Therapy for Inherited Diseases:** Advances in gene editing, like CRISPR, are offering new treatments for genetic disorders such as sickle cell anemia and inherited blindness.
#     *   **Application:** Treating a growing list of inherited and chronic diseases.
#     *   **Timeline:** Already in use, with expanding applications expected in the next 1-3 years.
#
# 2.  **AI in Diagnostics and Treatment:** AI is revolutionizing medical imaging for more accurate mammograms and improving early detection of heart conditions.
#     *   **Application:** Enhancing diagnostic accuracy and personalizing treatment plans.
#     *   **Timeline:** Current applications are rapidly expanding, with broader integration anticipated within 2-5 years.
#
# 3.  **Regenerative Medicine (3D Bioprinting):** Scientists are developing techniques to print cells and tissues, with the ultimate goal of creating whole organs for transplantation.
#     *   **Application:** Addressing organ shortages and advancing drug testing.
#     *   **Timeline:** Early stages with significant development needed; full organ printing is likely 10+ years away, but tissue engineering is closer.
#
# **Tech Breakthroughs:**
#
# 1.  **Agentic AI:** AI systems are evolving to act autonomously, planning and executing complex workflows, leading to "virtual coworkers."
#     *   **Application:** Automating tasks, improving efficiency in various industries.
#     *   **Timeline:** Rapid development, with practical applications expanding in the next 1-3 years.
#
# 2.  **Application-Specific Semiconductors:** Innovations in chip design are driven by the immense computing demands of AI.
#     *   **Application:** Powering advanced AI and high-performance computing.
#     *   **Timeline:** Development is ongoing, with significant impact expected within 2-5 years.
#
# 3.  **Quantum Computing Advancements:** IBM has unveiled new quantum computing developments, aiming for "quantum advantage" where quantum computers outperform classical ones.
#     *   **Application:** Revolutionizing fields like healthcare, finance, and materials science.
#     *   **Timeline:** Practical, widespread applications are still some years away, with quantum advantage targeted for late 2025 and broader impact in 5-10 years.
#
# **Finance Breakthroughs:**
#
# 1.  **AI-Augmented Due Diligence:** AI is streamlining borrower due diligence processes for lenders, significantly reducing review times and improving risk analysis.
#     *   **Application:** Enhancing efficiency, accuracy, and risk management in lending.
#     *   **Timeline:** Already being implemented, with wider adoption expected within 1-3 years.
#
# 2.  **Blockchain and Decentralized Finance (DeFi):** Blockchain continues to offer secure, decentralized platforms for financial services, impacting lending, smart contracts, and fraud screening.
#     *   **Application:** Transforming traditional banking infrastructure and reducing operational costs.
#     *   **Timeline:** Ongoing development and integration, with broader impact expected in the next 3-7 years.
#
# 3.  **Advanced Cryptography (Zero-Knowledge Proofs/Homomorphic Encryption):** These technologies enhance data privacy and security by allowing computations on encrypted data without decryption.
#     *   **Application:** Strengthening data security and privacy in financial transactions.
#     *   **Timeline:** Emerging applications with increased adoption projected within 3-7 years.
# AggregatorAgent > ## Executive Summary: Integrated Tech, Health, and Finance Landscape
#
# **Key Takeaway:** Artificial Intelligence (AI) is the unifying force across technology, health, and finance, driving significant advancements and transforming operational efficiency.
#
# **Common Themes & Surprising Connections:**
#
# *   **AI-Driven Automation & Efficiency:** Across all sectors, AI is central to automating complex tasks, enhancing decision-making, and improving efficiency. In **technology**, generative AI and AI agents are revolutionizing content creation and workflow management. **Finance** leverages AI for streamlined due diligence and personalized data synthesis, while **health** uses AI for advanced diagnostics and personalized treatment plans.
# *   **Data-Centric Innovation:** The rapid evolution of AI is underpinned by sophisticated data processing and analysis. This is evident in the development of AI infrastructure, specialized semiconductors, and advanced cryptographic techniques for secure data handling in finance.
# *   **Executive Briefings as a Convergence Point:** The way executives consume information is changing, with AI-powered tools now synthesizing complex data from calendars and multiple sources to provide concise, personalized summaries. This trend directly impacts how strategic decisions are made across all three domains.
# *   **Emerging Technologies with Cross-Sector Impact:** Quantum computing, though longer-term, holds the potential to revolutionize fields like healthcare and finance, while gene therapy in health and blockchain in finance represent disruptive innovations that will likely intersect with technological advancements.
#
# **Most Important Takeaways:**
#
# 1.  **AI is no longer just a tech trend; it's a foundational enabler across all industries.** Businesses must strategically integrate AI to remain competitive.
# 2.  **The demand for explainable and ethical AI is growing.** Building trust and ensuring fairness in AI systems is paramount, especially in regulated sectors like healthcare and finance.
# 3.  **The convergence of AI with specialized fields like gene therapy, regenerative medicine, and advanced cryptography presents unprecedented opportunities and challenges.** Staying abreast of these interdisciplinary advancements is critical for future strategy.
#
# This integrated approach highlights a future where AI-powered insights and autonomous systems will streamline operations, personalize services, and drive innovation across the entire economic landscape.

# %% [markdown]
# Example: Iterative Story Refinement

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("✅ initial_writer_agent created.")
# Out:
# ✅ initial_writer_agent created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}

    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("✅ critic_agent created.")
# Out:
# ✅ critic_agent created.

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("✅ exit_loop function created.")
# Out:
# ✅ exit_loop function created.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.

    Story Draft: {current_story}
    Critique: {critique}

    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("✅ refiner_agent created.")
# Out:
# ✅ refiner_agent created.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("✅ Loop and Sequential Agents created.")
# Out:
# ✅ Loop and Sequential Agents created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# InitialWriterAgent > Elias polished the Fresnel lens, the rhythmic sweep of light a familiar comfort against the encroaching dusk. For thirty years, the Sea Serpent’s Tooth lighthouse had been his world. Tonight, however, the sea churned with an unusual intensity, spitting foam high against the tower. As he secured the lantern room shutters, a glint caught his eye. A small, cylindrical object had washed ashore, nestled among the barnacle-encrusted rocks.
#
# He retrieved it, the object cool and smooth in his calloused hand. Unfurling it revealed not parchment, but a thin, iridescent membrane. Intricate lines, pulsing with a soft, cerulean glow, traced a path across its surface, leading to an island he’d never seen on any chart. A map, impossibly ancient and undeniably alive, had found its way to his solitary shore.
# CriticAgent > This is a promising start to a mystery! The imagery is strong and the premise intriguing. Here are a few suggestions to make it even better:
#
# 1.  **Deepen Elias's reaction and internal state:** While we know he's been a lighthouse keeper for thirty years and finds comfort in the light, we could explore his feelings more when he discovers this impossible map. Is he skeptical, fearful, or does a spark of long-dormant curiosity ignite? Showing his internal monologue or a physical reaction (a racing heart, a dropped tool) would make his discovery more impactful.
#
# 2.  **Enhance the description of the map's "aliveness":** The "pulsing with a soft, cerulean glow" is a great start. Consider adding more sensory details to emphasize its unusual nature. Does it feel warm or cool beyond being smooth? Does it make a faint sound, or seem to hum with energy? This will further solidify its otherworldly quality.
#
# 3.  **Hint at the "why" or "how":** While the mystery is part of the appeal, a slight nudge towards the map's origin could add another layer. Was there anything unusual about the storm, or a specific ship passing by that might be connected? Even a subtle suggestion can enrich the foreshadowing.
# RefinerAgent > Elias polished the Fresnel lens, its rhythmic sweep of light a familiar, almost hypnotic, comfort against the encroaching dusk. For thirty years, the Sea Serpent’s Tooth lighthouse had been his solitary world, a bulwark against the wild sea. Tonight, however, the ocean roared with an unusual ferocity, spitting plumes of icy foam high against the ancient stone tower. As he secured the lantern room shutters against the rising gale, a peculiar glint caught his eye far below. Amidst the barnacle-encrusted rocks, tossed by the unusually turbulent waves, lay a small, cylindrical object.
#
# A tremor of unease, quickly followed by a prickle of something akin to fear, ran through him. He descended the winding stairs, his heart thudding an unsteady rhythm against his ribs, a sensation long-forgotten. He retrieved the object, its surface startlingly cool and smooth against his calloused hand, unlike the rough embrace of the surrounding stone. With fumbling fingers, he unfurled it. It wasn't parchment, but a thin, iridescent membrane that seemed to shimmer with its own inner light. Intricate lines, etched in a soft, cerulean glow, pulsed with a faint, rhythmic energy that he could almost *feel* humming against his fingertips. It traced a path across its surface, leading to a jagged coastline – an island he’d never seen on any chart, no matter how many he’d pored over in his long tenure. This was no ordinary map; it felt ancient, impossibly so, and undeniably alive. A shiver, unrelated to the sea spray, traced its way down his spine. Had the storm brought this? Or something more… deliberate?
# CriticAgent > Critique of the story:
#
# *   **Plot:** The plot is set up effectively, introducing a mysterious object and its potential implications. The discovery of the unknown island on the map creates immediate intrigue and conflict.
# *   **Characters:** Elias is established as a solitary, experienced lighthouse keeper, whose long routine is disrupted by this discovery. His reaction of "unease" and "fear," coupled with a "sensation long-forgotten," hints at a deeper emotional landscape that could be explored.
# *   **Pacing:** The pacing is good. It starts with a descriptive build-up of the atmosphere and Elias's routine, then quickly moves to the inciting incident (finding the object) and its immediate aftermath. The suspense builds nicely as he examines the map.
#
# Suggestions for improvement:
#
# 1.  **Amplify Elias's internal conflict:** While "unease" and "fear" are present, Elias has been alone for thirty years. What does this discovery truly awaken in him? Is it the thrill of adventure he never knew he craved, or the terror of the unknown that his solitary life has shielded him from? Showing more of his internal debate between his ingrained caution and a burgeoning sense of wonder would add depth. For example, after unfurling the map, instead of just a shiver, perhaps he clutches his chest, breathes heavily, or even laughs a little, a sound that surprises even himself.
#
# 2.  **Integrate the sensory details of the map more seamlessly:** The description of the map is good, but some of the sensory details (cool, smooth, pulsing energy, humming) could be woven more directly into Elias's actions and immediate physical responses. For instance, when he unfurls it, mention the cool surface *against his skin*, or how the pulsing energy makes his fingertips tingle so intensely he almost drops it again. This would make the map's "aliveness" feel more immediate and visceral to the reader.
#
# 3.  **Strengthen the foreshadowing of "deliberate":** The question "Had the storm brought this? Or something more… deliberate?" is a good hook. To make this foreshadowing more potent, you could subtly hint at something more than just a storm. Perhaps the waves that tossed the object were unusually *shaped*, or there was a moment of unusual quiet *before* the object was spotted. Even a fleeting, strange sound Elias dismissed as the wind could enhance the feeling of intentionality.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
